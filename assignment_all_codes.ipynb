# %% [markdown]
# # *Downloading all the necessary libraries*

# %%
# !pip install pandas 
# !pip install requests 
# !pip install beautifulsoup4 
# !pip install openpyxl
# !pip install nltk
# !pip install syllapy
# Out:
# Requirement already satisfied: pandas in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hitesh\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hitesh\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: requests in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from requests) (2024.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: openpyxl in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: nltk in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\hitesh\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: syllapy in c:\users\hitesh\appdata\local\programs\python\python312\lib\site-packages (0.7.2)

# %% [markdown]
# # *Data Extraction*

# %% [markdown]
# ***While Data Extraction it was noticed that 2 articles particularily Article 36 and Article 49 was not available on the internet thus I removed those entries from the "Input.xlsx" and then performed all the analysis on the remaining Articles.***

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

def extract_article_content(soup):
    content_div = soup.find('div', class_='td-post-content tagdiv-type')
    if not content_div:
        content_div = soup.find('div', class_='td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type')

    if content_div:
        article_content = content_div.get_text(strip=True)
    else:
        article_content = ""
    return article_content

excel_file = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/Input.xlsx'
df = pd.read_excel(excel_file)

output_dir = 'articles_extracted_content'
os.makedirs(output_dir, exist_ok=True)

for index, row in df.iterrows():
    url_id = str(row['URL_ID'])
    url = row['URL']
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title_tag = soup.find('title')
        title = title_tag.get_text(strip=True) if title_tag else 'No Title Found'
        
        content = extract_article_content(soup)
        
        file_content = "Title: " + title + "\n\n\n" + content
        
        file_path = os.path.join(output_dir, url_id + ".txt")
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(file_content)
        
        print("Successfully saved: " + file_path)
        
    except requests.RequestException as e:
        print("Failed to fetch " + url + ": " + str(e))
    except Exception as e:
        print("An error occurred for " + url + ": " + str(e))
# Out:
# Successfully saved: articles_extracted_content\blackassign0001.txt
# Successfully saved: articles_extracted_content\blackassign0002.txt
# Successfully saved: articles_extracted_content\blackassign0003.txt
# Successfully saved: articles_extracted_content\blackassign0004.txt
# Successfully saved: articles_extracted_content\blackassign0005.txt
# Successfully saved: articles_extracted_content\blackassign0006.txt
# Successfully saved: articles_extracted_content\blackassign0007.txt
# Successfully saved: articles_extracted_content\blackassign0008.txt
# Successfully saved: articles_extracted_content\blackassign0009.txt
# Successfully saved: articles_extracted_content\blackassign0010.txt
# Successfully saved: articles_extracted_content\blackassign0011.txt
# Successfully saved: articles_extracted_content\blackassign0012.txt
# Successfully saved: articles_extracted_content\blackassign0013.txt
# Successfully saved: articles_extracted_content\blackassign0014.txt
# Successfully saved: articles_extracted_content\blackassign0015.txt
# Successfully saved: articles_extracted_content\blackassign0016.txt
# Successfully saved: articles_extracted_content\blackassign0017.txt
# Successfully saved: articles_extracted_content\blackassign0018.txt
# Successfully saved: articles_extracted_content\blackassign0019.txt
# Successfully saved: articles_extracted_content\blackassign0020.txt
# Successfully saved: articles_extracted_content\blackassign0021.txt
# Successfully saved: articles_extracted_content\blackassign0022.txt
# Successfully saved: articles_extracted_content\blackassign0023.txt
# Successfully saved: articles_extracted_content\blackassign0024.txt
# Successfully saved: articles_extracted_content\blackassign0025.txt
# Successfully saved: articles_extracted_content\blackassign0026.txt
# Successfully saved: articles_extracted_content\blackassign0027.txt
# Successfully saved: articles_extracted_content\blackassign0028.txt
# Successfully saved: articles_extracted_content\blackassign0029.txt
# Successfully saved: articles_extracted_content\blackassign0030.txt
# Successfully saved: articles_extracted_content\blackassign0031.txt
# Successfully saved: articles_extracted_content\blackassign0032.txt
# Successfully saved: articles_extracted_content\blackassign0033.txt
# Successfully saved: articles_extracted_content\blackassign0034.txt
# Successfully saved: articles_extracted_content\blackassign0035.txt
# Successfully saved: articles_extracted_content\blackassign0037.txt
# Successfully saved: articles_extracted_content\blackassign0038.txt
# Successfully saved: articles_extracted_content\blackassign0039.txt
# Successfully saved: articles_extracted_content\blackassign0040.txt
# Successfully saved: articles_extracted_content\blackassign0041.txt
# Successfully saved: articles_extracted_content\blackassign0042.txt
# Successfully saved: articles_extracted_content\blackassign0043.txt
# Successfully saved: articles_extracted_content\blackassign0044.txt
# Successfully saved: articles_extracted_content\blackassign0045.txt
# Successfully saved: articles_extracted_content\blackassign0046.txt
# Successfully saved: articles_extracted_content\blackassign0047.txt
# Successfully saved: articles_extracted_content\blackassign0048.txt
# Successfully saved: articles_extracted_content\blackassign0050.txt
# Successfully saved: articles_extracted_content\blackassign0051.txt
# Successfully saved: articles_extracted_content\blackassign0052.txt
# Successfully saved: articles_extracted_content\blackassign0053.txt
# Successfully saved: articles_extracted_content\blackassign0054.txt
# Successfully saved: articles_extracted_content\blackassign0055.txt
# Successfully saved: articles_extracted_content\blackassign0056.txt
# Successfully saved: articles_extracted_content\blackassign0057.txt
# Successfully saved: articles_extracted_content\blackassign0058.txt
# Successfully saved: articles_extracted_content\blackassign0059.txt
# Successfully saved: articles_extracted_content\blackassign0060.txt
# Successfully saved: articles_extracted_content\blackassign0061.txt
# Successfully saved: articles_extracted_content\blackassign0062.txt
# Successfully saved: articles_extracted_content\blackassign0063.txt
# Successfully saved: articles_extracted_content\blackassign0064.txt
# Successfully saved: articles_extracted_content\blackassign0065.txt
# Successfully saved: articles_extracted_content\blackassign0066.txt
# Successfully saved: articles_extracted_content\blackassign0067.txt
# Successfully saved: articles_extracted_content\blackassign0068.txt
# Successfully saved: articles_extracted_content\blackassign0069.txt
# Successfully saved: articles_extracted_content\blackassign0070.txt
# Successfully saved: articles_extracted_content\blackassign0071.txt
# Successfully saved: articles_extracted_content\blackassign0072.txt
# Successfully saved: articles_extracted_content\blackassign0073.txt
# Successfully saved: articles_extracted_content\blackassign0074.txt
# Successfully saved: articles_extracted_content\blackassign0075.txt
# Successfully saved: articles_extracted_content\blackassign0076.txt
# Successfully saved: articles_extracted_content\blackassign0077.txt
# Successfully saved: articles_extracted_content\blackassign0078.txt
# Successfully saved: articles_extracted_content\blackassign0079.txt
# Successfully saved: articles_extracted_content\blackassign0080.txt
# Successfully saved: articles_extracted_content\blackassign0081.txt
# Successfully saved: articles_extracted_content\blackassign0082.txt
# Successfully saved: articles_extracted_content\blackassign0083.txt
# Successfully saved: articles_extracted_content\blackassign0084.txt
# Successfully saved: articles_extracted_content\blackassign0085.txt
# Successfully saved: articles_extracted_content\blackassign0086.txt
# Successfully saved: articles_extracted_content\blackassign0087.txt
# Successfully saved: articles_extracted_content\blackassign0088.txt
# Successfully saved: articles_extracted_content\blackassign0089.txt
# Successfully saved: articles_extracted_content\blackassign0090.txt
# Successfully saved: articles_extracted_content\blackassign0091.txt
# Successfully saved: articles_extracted_content\blackassign0092.txt
# Successfully saved: articles_extracted_content\blackassign0093.txt
# Successfully saved: articles_extracted_content\blackassign0094.txt
# Successfully saved: articles_extracted_content\blackassign0095.txt
# Successfully saved: articles_extracted_content\blackassign0096.txt
# Successfully saved: articles_extracted_content\blackassign0097.txt
# Successfully saved: articles_extracted_content\blackassign0098.txt
# Successfully saved: articles_extracted_content\blackassign0099.txt
# Successfully saved: articles_extracted_content\blackassign0100.txt

# %% [markdown]
# # *Data Cleaning and Pre-Processing*

# %%
import os
import re

def load_stop_words(stop_words_dir):
    stop_words = set()
    for file_name in os.listdir(stop_words_dir):
        file_path = os.path.join(stop_words_dir, file_name)
        stop_words.update(read_file_with_encodings(file_path))
    return stop_words

def read_file_with_encodings(file_path):
    encodings = ['utf-8', 'latin-1', 'ISO-8859-1']
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                return {line.strip().lower() for line in file}
        except UnicodeDecodeError:
            continue
    raise UnicodeDecodeError("Cannot decode file " + file_path + " with available encodings")

def remove_punctuation(text):
    return re.sub(r'[?!.;,:-]', '', text)

def remove_stop_words(text, stop_words):
    words = text.split()
    filtered_words = [remove_punctuation(word) for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

stop_words_dir = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/StopWords'
articles_dir = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/articles_extracted_content'
cleaned_articles_dir = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles'

stop_words = load_stop_words(stop_words_dir)
os.makedirs(cleaned_articles_dir, exist_ok=True)

for file_name in os.listdir(articles_dir):
    file_path = os.path.join(articles_dir, file_name)
    
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
    title = lines[0].strip()
    content = ' '.join(line.strip() for line in lines[2:])
    cleaned_content = remove_stop_words(content, stop_words)
    cleaned_file_content = title + "\n\n\n" + cleaned_content
    cleaned_file_path = os.path.join(cleaned_articles_dir, file_name)
    with open(cleaned_file_path, 'w', encoding='utf-8') as cleaned_file:
        cleaned_file.write(cleaned_file_content)
    
    print("Successfully cleaned and saved:", cleaned_file_path)

print("Cleaning process completed.")
# Out:
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0001.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0002.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0003.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0004.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0005.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0006.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0007.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0008.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0009.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0010.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0011.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0012.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0013.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0014.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0015.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0016.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0017.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0018.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0019.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0020.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0021.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0022.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0023.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0024.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0025.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0026.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0027.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0028.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0029.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0030.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0031.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0032.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0033.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0034.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0035.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0037.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0038.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0039.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0040.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0041.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0042.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0043.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0044.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0045.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0046.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0047.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0048.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0050.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0051.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0052.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0053.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0054.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0055.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0056.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0057.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0058.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0059.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0060.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0061.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0062.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0063.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0064.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0065.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0066.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0067.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0068.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0069.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0070.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0071.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0072.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0073.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0074.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0075.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0076.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0077.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0078.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0079.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0080.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0081.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0082.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0083.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0084.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0085.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0086.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0087.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0088.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0089.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0090.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0091.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0092.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0093.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0094.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0095.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0096.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0097.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0098.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0099.txt
# Successfully cleaned and saved: C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles\blackassign0100.txt
# Cleaning process completed.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HITESH\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# # *Performing the Sentiment Analysis and creating the Excel file*

# %%
import pandas as pd
import os
from nltk.tokenize import word_tokenize, sent_tokenize
import re

def load_master_dictionary(positive_file, negative_file):
    positive_words = read_file_with_encodings(positive_file)
    negative_words = read_file_with_encodings(negative_file)
    return positive_words, negative_words

def read_file_with_encodings(file_path):
    encodings = ['utf-8', 'latin-1', 'ISO-8859-1']
    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as file:
                words = {line.strip().lower() for line in file}
            return words
        except UnicodeDecodeError:
            continue
    raise UnicodeDecodeError("Cannot decode file " + file_path + " with available encodings")

def count_syllables(word):
    word = word.lower()
    word = re.sub(r'[^a-z]', '', word)  # Remove non-alphabet characters
    if word.endswith('es') or word.endswith('ed'):
        word = word[:-2]
    syllable_count = sum(1 for char in word if char in 'aeiou')
    syllable_count = max(syllable_count, 1)  # Ensure at least one syllable
    return syllable_count

def count_complex_words(tokens):
    return sum(1 for token in tokens if count_syllables(token) > 2)

def count_personal_pronouns(text):
    pronouns_pattern = r'\b(i|we|my|ours|us)\b(?!\bUS\b)'
    pronouns = re.findall(pronouns_pattern, text, re.IGNORECASE)
    return len(pronouns)

def calculate_average_word_length(tokens):
    total_characters = sum(len(token) for token in tokens)
    average_word_length = total_characters / (len(tokens) + 0.000001)
    return average_word_length

def scores_and_matrices(text, positive_words, negative_words):
    tokens = word_tokenize(text.lower())
    sentences = sent_tokenize(text)
    total_words = len(tokens)
    total_sentences = len(sentences)
    
    positive_score = sum(1 for token in tokens if token in positive_words)
    negative_score = sum(1 for token in tokens if token in negative_words)
    polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (total_words + 0.000001)
    
    average_sentence_length = total_words / total_sentences
    complex_words_count = count_complex_words(tokens)
    percentage_complex_words = complex_words_count / total_words
    fog_index = 0.4 * (average_sentence_length + percentage_complex_words)
    average_number_words_per_sentence = total_words / total_sentences
    
    syllable_counts = [count_syllables(word) for word in tokens]
    
    personal_pronouns_count = count_personal_pronouns(text)
    average_word_length = calculate_average_word_length(tokens)
    
    return (positive_score, negative_score, polarity_score, subjectivity_score, 
            average_sentence_length, percentage_complex_words, fog_index, 
            average_number_words_per_sentence, syllable_counts, complex_words_count, 
            total_words, personal_pronouns_count, average_word_length)

cleaned_articles_dir = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/cleaned_articles'
positive_words_file = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/MasterDictionary/positive-words.txt'
negative_words_file = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/MasterDictionary/negative-words.txt'
final_submission_file = 'C:/Users/HITESH/OneDrive/Desktop/BlackCoffer/Final_Submission.xlsx'

positive_words, negative_words = load_master_dictionary(positive_words_file, negative_words_file)
article_files = os.listdir(cleaned_articles_dir)

final_submission_data = []

for file_name in article_files:
    file_path = os.path.join(cleaned_articles_dir, file_name)
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()
    
    (positive_score, negative_score, polarity_score, subjectivity_score, 
     average_sentence_length, percentage_complex_words, fog_index, 
     average_number_words_per_sentence, syllable_counts, complex_words_count, 
     total_words, personal_pronouns_count, average_word_length) = scores_and_matrices(text, positive_words, negative_words)

    url_id = file_name.split('.')[0]
    url = ""
    
    final_submission_data.append({
        'URL_ID': url_id,
        'URL': url,
        'POSITIVE SCORE': positive_score,
        'NEGATIVE SCORE': negative_score,
        'POLARITY SCORE': polarity_score,
        'SUBJECTIVITY SCORE': subjectivity_score,
        'AVG SENTENCE LENGTH': average_sentence_length,
        'PERCENTAGE OF COMPLEX WORDS': percentage_complex_words,
        'FOG INDEX': fog_index,
        'AVG NUMBER OF WORDS PER SENTENCE': average_number_words_per_sentence,
        'COMPLEX WORD COUNT': complex_words_count,
        'WORD COUNT': total_words,
        'SYLLABLE PER WORD': syllable_counts,
        'PERSONAL PRONOUNS': personal_pronouns_count,
        'AVG WORD LENGTH': average_word_length
    })

final_submission_df = pd.DataFrame(final_submission_data)
final_submission_df.to_excel(final_submission_file, index=False)

print("Scores calculated and Final Submission Excel file created successfully.")
# Out:
# Scores calculated and Final Submission Excel file created successfully.

# %% [markdown]
# # ***Thank You***
